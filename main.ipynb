# %%
import PyPDF2

def extract_text_from_pdf(pdf_path):
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        text = ''
        for page_num in range(len(reader.pages)):
            page = reader.pages[page_num]
            text += page.extract_text()
    return text

pdf_path = "دليل الموظف المستجد - أحمد متولي.pdf"
pdf_text = extract_text_from_pdf(pdf_path)

# %%
pdf_text
# Out:
# 'دليل الموظف المستجد. دليل الموظف المستجدالعنوان: \n أحمد متولي.المؤلف: \n.2019 تم الانتهاء من الكتاب في إبريل\nكافة الحقوق محفوظة للمؤلف. \nلا يجوز إعادة إنتاج أي جزء من هذا الكتاب أو نقله بأي شكل \nاو بأية وسيلة سواء كانت إللكترونية أو ميكانيكية، بما في ذلك التصوير \nالفوتوغرافي أو التسجيل الصوتي أو وسائل تخزين المعلومات بدون إذن \nكتابي من المؤلف. \n 2020/15189  :رقم الإيداع\n978-977-990-009-4  :الترقيم الدولي\nللتواصل مع المؤلف:\nfacebook.com/ahmed.metwally.official\nlinkedin.com/in/metwallyدليل الموظف المستجد\nأحمد متولي\nحترف.. جدًا� موظف م إنــه مخطــئ، ال تحتــاج للكثــر مــن القــوة للضغــط عــى الزنــاد، لكــن «\n حــاول إن تســتيقظ كل يــوم يف الصبــاح يومًــا بعــد يــوم والذهــاب إىل العمل \nمــن أجــل كســب العيــش. ودعنــا نــراه يجــرب هــذا، ثــم بعــد ذلــك ســوف \nتــرى مــن هــو الرجــل القــوي حقًــا، الرجــل العامــل هــو الرجــل القــوي، \n».أبــوك هــو الرجــل القــوي \nA Bronx Tale  روبرت دي نريو، من فيلم.حين دون شكوى�إلى هؤلاء المكافأحمد متولي7\nمقدمة البد م
# ...

# %%
import fasttext

# Load FastText Arabic word vectors
ft = fasttext.load_model('cc.ar.300.bin')

def get_sentence_embedding(sentence):
    words = sentence.split()
    embeddings = [ft.get_word_vector(word) for word in words]
    return np.mean(embeddings, axis=0)

# Example usage
sentence_embedding = get_sentence_embedding("مرحبا كيف حالك")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import fasttext
#       3 # Load FastText Arabic word vectors
#       4 ft = fasttext.load_model('cc.ar.300.bin')
#
# ModuleNotFoundError: No module named 'fasttext'
